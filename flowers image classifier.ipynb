# %% [markdown]
# ***Flowers Image Classifier***
#
# ***DEEP LEARNING PROJECT IMAGE CLASSIFICATION OF FLOWERS WITH DATA AUGUMENTATION***

# %% [markdown]
# #Image Classification using tf.keras**

# %% [markdown]
# #Importing Packages
#
# Let's start by importing required packages. os package is used to read files and directory structure, numpy is used to convert python list to numpy array and to perform required matrix operations and matplotlib.pyplot is used to plot the graph and display images in our training and validation data.

# %%
import os
import numpy as np
import glob
import shutil
import matplotlib.pyplot as plt

# %% [markdown]
# #Import TensorFlow and Keras Layers

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# **Data Loading**

# %%
_URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

zip_file = tf.keras.utils.get_file(origin=_URL,
                                   fname="flower_photos.tgz",
                                   extract=True)

base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 1s 0us/step
# 228827136/228813984 [==============================] - 1s 0us/step

# %%
classes = ['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips']

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print("{}: {} Images".format(cl, len(images)))
  num_train = int(round(len(images)*0.8))
  train, val = images[:num_train], images[num_train:]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# roses: 641 Images
# daisy: 633 Images
# dandelion: 898 Images
# sunflowers: 699 Images
# tulips: 799 Images

# %%
round(len(images)*0.8)
# Out:
# 639

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

# %% [markdown]
# #Data Augmentation

# %% [markdown]
# **Set Batch and Image Size**

# %%
batch_size = 100
IMG_SHAPE = 150

# %% [markdown]
# #Apply Random Horizontal Flip

# %%
image_gen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)

train_data_gen = image_gen.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE)
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()


augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# #Apply Random Rotation

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range=45)

train_data_gen = image_gen.flow_from_directory(batch_size=batch_size,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# #Apply Random Zoom

# %%
image_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.5)

train_data_gen = image_gen.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE, IMG_SHAPE)
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# #Put It All Together

# %%
image_gen_train = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )


train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='sparse'
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# #Create a Data Generator for the Validation Set

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size,
                                                 directory=val_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')
# Out:
# Found 735 images belonging to 5 classes.

# %% [markdown]
# #Create the CNN

# %%
model = Sequential()

model.add(Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(5))

# %% [markdown]
# #Compile the Model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #Train the Model

# %%
epochs = 80

history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(batch_size))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(batch_size)))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/80
# 30/30 [==============================] - 88s 3s/step - loss: 1.1150 - accuracy: 0.5380 - val_loss: 1.0000 - val_accuracy: 0.6177
# Epoch 2/80
# 30/30 [==============================] - 88s 3s/step - loss: 1.0665 - accuracy: 0.5901 - val_loss: 1.0053 - val_accuracy: 0.6068
# Epoch 3/80
# 30/30 [==============================] - 87s 3s/step - loss: 1.0131 - accuracy: 0.5922 - val_loss: 0.9725 - val_accuracy: 0.6381
# Epoch 4/80
# 30/30 [==============================] - 88s 3s/step - loss: 0.9816 - accuracy: 0.6201 - val_loss: 0.8812 - val_accuracy: 0.6694
# Epoch 5/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.9469 - accuracy: 0.6392 - val_loss: 0.8863 - val_accuracy: 0.6612
# Epoch 6/80
# 30/30 [==============================] - 88s 3s/step - loss: 0.9156 - accuracy: 0.6412 - val_loss: 0.8397 - val_accuracy: 0.6816
# Epoch 7/80
# 30/30 [==============================] - 88s 3s/step - loss: 0.8870 - accuracy: 0.6538 - val_loss: 0.8071 - val_accuracy: 0.6952
# Epoch 45/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.5512 - accuracy: 0.7881 - val_loss: 0.6995 - val_accuracy: 0.7605
# Epoch 46/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.5432 - accuracy: 0.7901 - val_loss: 0.6971 - val_accuracy: 0.7578
# Epoch 47/80
# 30/30 [==============================] - 90s 3s/step - loss: 0.5276 - accuracy: 0.7976 - val_loss: 0.7424 - val_accuracy: 0.7537
# Epoch 48/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.5395 - accuracy: 0.7928 - val_loss: 0.6507 - val_accuracy: 0.7769
# Epoch 49/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.5272 - accuracy: 0.7935 - val_loss: 0.7175 - val_accuracy: 0.7565
# Epoch 50/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.5112 - accuracy: 0.8044 - val_loss: 0.6719 - val_accuracy: 0.7769
# Epoch 51/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.4939 - accuracy: 0.8017 - val_loss: 0.7060 - val_accuracy: 0.7633
# Epoch 52/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.5051 - accuracy: 0.8092 - val_loss: 0.7172 - val_accuracy: 0.7565
# Epoch 53/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.4949 - accuracy: 0.8034 - val_loss: 0.7001 - val_accuracy: 0.7687
# Epoch 54/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.4836 - accuracy: 0.7990 - val_loss: 0.6714 - val_accuracy: 0.7714
# Epoch 55/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.4650 - accuracy: 0.8262 - val_loss: 0.6710 - val_accuracy: 0.7810
# Epoch 56/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.4842 - accuracy: 0.8072 - val_loss: 0.7497 - val_accuracy: 0.7469
# Epoch 57/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.4778 - accuracy: 0.8181 - val_loss: 0.6258 - val_accuracy: 0.7850
# Epoch 58/80
# 30/30 [==============================] - 87s 3s/step - loss: 0.4530 - accuracy: 0.8290 - val_loss: 0.6547 - val_accuracy: 0.7850
# Epoch 59/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4915 - accuracy: 0.8133 - val_loss: 0.7652 - val_accuracy: 0.7551
# Epoch 60/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4650 - accuracy: 0.8249 - val_loss: 0.7171 - val_accuracy: 0.7701
# Epoch 61/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4487 - accuracy: 0.8266 - val_loss: 0.7447 - val_accuracy: 0.7537
# Epoch 62/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4661 - accuracy: 0.8249 - val_loss: 0.6760 - val_accuracy: 0.7673
# Epoch 63/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4611 - accuracy: 0.8204 - val_loss: 0.6958 - val_accuracy: 0.7646
# Epoch 64/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4272 - accuracy: 0.8344 - val_loss: 0.6821 - val_accuracy: 0.7714
# Epoch 65/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4407 - accuracy: 0.8310 - val_loss: 0.8438 - val_accuracy: 0.7483
# Epoch 66/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4542 - accuracy: 0.8296 - val_loss: 0.7119 - val_accuracy: 0.7755
# Epoch 67/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4425 - accuracy: 0.8320 - val_loss: 0.7013 - val_accuracy: 0.7796
# Epoch 68/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4288 - accuracy: 0.8344 - val_loss: 0.6344 - val_accuracy: 0.7755
# Epoch 69/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4196 - accuracy: 0.8368 - val_loss: 0.6726 - val_accuracy: 0.7810
# Epoch 70/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4143 - accuracy: 0.8422 - val_loss: 0.6921 - val_accuracy: 0.7837
# Epoch 71/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4076 - accuracy: 0.8457 - val_loss: 0.7260 - val_accuracy: 0.7592
# Epoch 72/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4192 - accuracy: 0.8422 - val_loss: 0.6784 - val_accuracy: 0.7769
# Epoch 73/80
# 30/30 [==============================] - 90s 3s/step - loss: 0.4255 - accuracy: 0.8361 - val_loss: 0.7361 - val_accuracy: 0.7578
# Epoch 74/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4063 - accuracy: 0.8453 - val_loss: 0.7204 - val_accuracy: 0.7769
# Epoch 75/80
# 30/30 [==============================] - 90s 3s/step - loss: 0.4143 - accuracy: 0.8457 - val_loss: 0.7059 - val_accuracy: 0.7769
# Epoch 76/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4209 - accuracy: 0.8307 - val_loss: 0.7401 - val_accuracy: 0.7701
# Epoch 77/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.4156 - accuracy: 0.8494 - val_loss: 0.7641 - val_accuracy: 0.7660
# Epoch 78/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.3998 - accuracy: 0.8491 - val_loss: 0.7218 - val_accuracy: 0.7810
# Epoch 79/80
# 30/30 [==============================] - 90s 3s/step - loss: 0.3888 - accuracy: 0.8497 - val_loss: 0.7082 - val_accuracy: 0.7810
# Epoch 80/80
# 30/30 [==============================] - 91s 3s/step - loss: 0.3849 - accuracy: 0.8460 - val_loss: 0.7126 - val_accuracy: 0.7673

# %% [markdown]
# #Plot Training and Validation Graphs.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #THANK YOU
# #END OF THE PROJECT
